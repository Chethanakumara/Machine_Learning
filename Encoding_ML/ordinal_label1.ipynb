# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df= pd.read_csv('ordinal_label_encoding.csv')

# %%
df.sample(15)
# Out:
#     Customer_ID Education_Level Satisfaction  Gender  Income  Age  \
# 33           34        Bachelor          Low    Male   32049   43
# 91           92             PhD         High  Female   79377   26
# 50           51          Master          Low  Female   42874   25
# 38           39     High School          Low    Male  102694   56
# 19           20          Master          Low  Female   67504   35
# 62           63     High School          Low  Female   51357   42
# 59           60     High School       Medium    Male   32200   49
# 42           43        Bachelor          Low  Female   45151   52
# 49           50        Bachelor       Medium  Female   59299   18
# 84           85          Master          Low  Female   77333   34
# 21           22     High School          Low  Female   38155   59
# 64           65          Master         High  Female   32869   39
# 3             4          Master       Medium  Female   45708   47
# ...

# %%
x=df[['Education_Level','Satisfaction']]
y = df['Region']

# %%
y
# Out:
# 0      West
# 1      West
# 2     North
# 3      West
# 4     South
#       ...
# 95    South
# 96    North
# 97    South
# 98    North
# 99     East
# Name: Region, Length: 100, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y , test_size=0.2 , random_state = 32)

# %%
y_test.shape
# Out:
# (20,)

# %%
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder

# %%
df
# Out:
#     Customer_ID Education_Level Satisfaction  Gender  Income  Age  \
# 0             1          Master         High  Female   72107   52
# 1             2             PhD       Medium  Female  116202   34
# 2             3     High School       Medium  Female   81663   45
# 3             4          Master       Medium  Female   45708   47
# 4             5          Master       Medium  Female   79811   46
# ..          ...             ...          ...     ...     ...  ...
# 95           96        Bachelor          Low    Male   35600   51
# 96           97        Bachelor       Medium    Male   70764   49
# 97           98             PhD          Low  Female  104543   42
# 98           99        Bachelor          Low  Female   75714   57
# 99          100     High School       Medium    Male   86835   18
#
#     Spending_Score Product_Category Loyalty_Level Region
# 0               16        Groceries        Silver   West
# 1               61        Furniture          Gold   West
# ...

# %%
loyalty_order = ['High School', 'Master', 'Bachelor', 'PhD']

satisfaction_order = ['Low', 'Medium', 'High']

# %%
# Create encoders
ordinal_enc = OrdinalEncoder(categories=[ loyalty_order,satisfaction_order])

# %%
ode = ordinal_enc.fit_transform(x_train)
odt = ordinal_enc.transform(x_test)

# %%
x_test
# Out:
#    Education_Level Satisfaction
# 22        Bachelor          Low
# 39          Master       Medium
# 85          Master         High
# 97             PhD          Low
# 55             PhD          Low
# 33        Bachelor          Low
# 80          Master       Medium
# 13          Master          Low
# 27        Bachelor         High
# 96        Bachelor       Medium
# 44             PhD          Low
# 46             PhD          Low
# 58          Master         High
# 23             PhD         High
# 48        Bachelor         High
# 84          Master          Low
# 2      High School       Medium
# 66             PhD       Medium
# 63     High School       Medium
# 36             PhD          Low

# %%
ordinal_enc.categories_
# Out:
# [array(['High School', 'Master', 'Bachelor', 'PhD'], dtype=object),
#  array(['Low', 'Medium', 'High'], dtype=object)]

# %%
le = LabelEncoder()

# %%
le.fit(y_train)
# Out:
# LabelEncoder()

# %%
le.classes_
# Out:
# array(['East', 'North', 'South', 'West'], dtype=object)

# %%
y_train = le.transform(y_train)
y_test = le.transform(y_test)

# %%
y_train
# Out:
# array([1, 3, 2, 3, 1, 1, 0, 1, 3, 1, 2, 1, 0, 3, 2, 3, 1, 3, 1, 1, 3, 0,
#        3, 0, 0, 3, 1, 1, 2, 2, 2, 0, 1, 2, 0, 1, 1, 1, 0, 2, 0, 1, 1, 3,
#        3, 1, 1, 3, 0, 0, 2, 1, 1, 2, 0, 1, 2, 1, 3, 3, 2, 1, 2, 2, 0, 2,
#        0, 2, 2, 2, 3, 1, 0, 2, 1, 1, 2, 3, 3, 1])
